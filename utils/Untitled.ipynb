# %%
import requests

url = "https://raw.githubusercontent.com/marcosjantsch/shapefile-viewer/main/DadosOnline/resumo_2000.csv"

r = requests.get(url)

print("status:", r.status_code)
print("content-type:", r.headers.get("Content-Type"))
print(r.text[:200])
# Out:
# status: 200
# content-type: text/plain; charset=utf-8
# ﻿ANO;MES;DATA;EMPRESA;FAZENDA;UF;MUNICIPIO;AREA_T;AREA_PRODU;PRECIP_CHIRPS_MM;TEMP_MEDIA_C;UMID_MEDIA_PCT;TEMP_MIN_C;UMID_MIN_PCT;TEMP_MAX_C;UMID_MAX_PCT;NOITES_FRIAS_Eucalipto_<15C;NOITES_FRIAS_Pinus
