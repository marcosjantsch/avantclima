# %%
import requests

r = requests.get(url_direto, allow_redirects=True, timeout=60)

print("status:", r.status_code)
print("final_url:", r.url)
print("content-type:", r.headers.get("Content-Type"))
print("tamanho:", len(r.content))
print("preview:", r.content[:100])
# Out:
# status: 401
# final_url: https://api.onedrive.com/v1.0/shares/u!aHR0cHM6Ly8xZHJ2Lm1zL3gvYy84Yjg4YjgxYzA2NDU0M2QzL0lRQld2VEJWRVhUVlFLUDI4OHp4QzlOTkFSZDJrSk1IRldlY210ZUlhaXRTRG9NP2U9Z29UQnBJ/root/content
# content-type: application/json;charset=utf-8
# tamanho: 165
# preview: b'{"error":{"code":"unauthenticated","message":"Exception of type \'Microsoft.Vroom.Exceptions.Unauthen'
